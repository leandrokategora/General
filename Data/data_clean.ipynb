# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date

# %%
data_netflix = pd.read_csv('./netflix_titles_data.csv', sep=';', encoding='UTF-8')
df_netflix = pd.DataFrame(data_netflix)

data_disney = pd.read_csv('./disney_plus_titles_data.csv', sep=',', encoding='UTF-8')
df_disney = pd.DataFrame(data_disney)

# %% [markdown]
# **Iniciamos con un analisis exploratorio de los datos para determinar que campos tenemos, que tipo de dato estan almacenando y que cantidad de informacion nula hay en el archivo original**

# %%
df_netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_disney.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year    object
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_disney.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating           object
# duration         object
# listed_in        object
# description      object
# Id_plataforma     int64
# dtype: object

# %%
df_disney.sample(5)
# Out:
#      show_id     type                                             title  \
# 58       s59  TV Show                                          PJ Masks
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 658     s659    Movie                        Drain The Bermuda Triangle
# 919     s920  TV Show                                        Goof Troop
# 1066   s1067    Movie                                  Meet the Deedles
#
#                                director  \
# 58                                  NaN
# 0     Alonso Ramirez Ramos, Dave Wasson
# 658                       Jobim Sampson
# 919                                 NaN
# 1066                        Steve Boyum
#
#                                                    cast  \
# 58      Kyle Breitkopf, Jacob Ursomarzo, Addison Holley
# 0     Chris Diamantopoulos, Tony Anselmo, Tress MacN...
# 658                                     Russell Boulter
# 919   Nancy Cartwright, Jim Cummings, Dana Hill, Rob...
# 1066  Paul Walker, Steve Wormer, John Ashton, A.J. L...
#
#                      country         date_added  release_year rating  \
# 58    France, United Kingdom   October 20, 2021          2015  TV-Y7
# 0                        NaN  November 26, 2021          2016   TV-G
# 658            United States    January 1, 2020          2014  TV-PG
# 919            United States  November 12, 2019          1992  TV-Y7
# 1066           United States  November 12, 2019          1998     PG
#
#        duration                          listed_in  \
# 58    5 Seasons  Action-Adventure, Animation, Kids
# 0        23 min                  Animation, Family
# 658      45 min                        Documentary
# 919    1 Season            Animation, Comedy, Kids
# 1066     94 min                      Buddy, Comedy
#
#                                             description
# 58    Look out Night Time Baddies the PJ Masks are c...
# 0      Join Mickey and the gang as they duck the halls!
# 658   Explore the Bermuda Triangle by draining the w...
# 919   Goofy is a single father raising his son, Max ...
# 1066  Two surfer dudes try to stop an ex-park ranger...

# %%
df_netflix.sample(5)
# Out:
#      show_id   type                                              title  \
# 7150   s7151  Movie                                            Junebug
# 1518   s1519  Movie  Ma Rainey's Black Bottom: A Legacy Brought to ...
# 8531   s8530  Movie                                   The Tiger Hunter
# 2278   s2279  Movie                                           Mary Kom
# 6087   s6088  Movie                                   Act of Vengeance
#
#                director                                               cast  \
# 7150      Phil Morrison  Amy Adams, Embeth Davidtz, Ben McKenzie, Aless...
# 1518                NaN  Glynn Turman, Denzel Washington, George C. Wol...
# 8531          Lena Khan  Danny Pudi, Jon Heder, Rizwan Manji, Karen Dav...
# 2278        Omung Kumar  Priyanka Chopra, Darshan Kumar, Sunil Thapa, K...
# 6087  Mahsun Kırmızıgül  Haluk Bilginer, Mahsun Kırmızıgül, Mustafa San...
#
#                     country          date_added release_year rating duration  \
# 7150          United States       March 1, 2019         2005      R  107 min
# 1518                    NaN   December 18, 2020         2020  TV-PG   32 min
# 8531          United States       April 9, 2018         2016  TV-14   94 min
# 2278                  India        July 5, 2020         2014  TV-PG  120 min
# 6087  Turkey, United States  September 29, 2018         2010     NR  112 min
#
#                                         listed_in  \
# 7150         Comedies, Dramas, Independent Movies
# 1518              Documentaries, Music & Musicals
# 8531         Comedies, Dramas, Independent Movies
# 2278  Dramas, International Movies, Sports Movies
# 6087     Action & Adventure, International Movies
#
#                                             description
# 7150  When a big-city art dealer travels to North Ca...
# 1518  Viola Davis, Denzel Washington, George C. Wolf...
# 8531  It's 1979, and engineer Sami is excited to lea...
# 2278  The daughter of a poor rice farmer overcomes t...
# 6087  Two Turkish agents are sent to New York City o...

# %%
df_netflix.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8809   8808                  8807           6173
# unique    8809      3                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added release_year  \
# count                 7983           7976             8797         8807
# unique                7693            749             1768           75
# top     David Attenborough  United States  January 1, 2020         2018
# freq                    19           2817              109         1147
#
#        rating  duration                     listed_in  \
# count    8803      8804                          8806
# unique     18       221                           514
# top     TV-MA  1 Season  Dramas, International Movies
# freq     3207      1793                           362
#
#                                               description
# count                                                8806
# unique                                               8774
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %%
df_disney.describe(include='all')
# Out:
#        show_id   type                                             title  \
# count     1450   1450                                              1450
# unique    1450      2                                              1450
# top         s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# freq         1   1052                                                 1
# mean       NaN    NaN                                               NaN
# std        NaN    NaN                                               NaN
# min        NaN    NaN                                               NaN
# 25%        NaN    NaN                                               NaN
# 50%        NaN    NaN                                               NaN
# 75%        NaN    NaN                                               NaN
# max        NaN    NaN                                               NaN
#
#            director            cast        country         date_added  \
# count           977            1260           1231               1447
# unique          609            1193             89                167
# top     Jack Hannah  Winston Hibler  United States  November 12, 2019
# freq             17              10           1005                722
# mean            NaN             NaN            NaN                NaN
# std             NaN             NaN            NaN                NaN
# min             NaN             NaN            NaN                NaN
# 25%             NaN             NaN            NaN                NaN
# 50%             NaN             NaN            NaN                NaN
# 75%             NaN             NaN            NaN                NaN
# max             NaN             NaN            NaN                NaN
#
#         release_year rating  duration                  listed_in  \
# count    1450.000000   1447      1450                       1450
# unique           NaN      9       158                        329
# top              NaN   TV-G  1 Season  Animation, Comedy, Family
# freq             NaN    318       219                        124
# mean     2003.091724    NaN       NaN                        NaN
# std        21.860162    NaN       NaN                        NaN
# min      1928.000000    NaN       NaN                        NaN
# 25%      1999.000000    NaN       NaN                        NaN
# 50%      2011.000000    NaN       NaN                        NaN
# 75%      2018.000000    NaN       NaN                        NaN
# max      2021.000000    NaN       NaN                        NaN
#
#                                               description
# count                                                1450
# unique                                               1448
# top     Cooper and Cami Wrather co-host "Would You Wra...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# **Una vez realizado un analisis inicial de los datos es posible determinar que en la plataforma de "Disney  Plus" los datos estan mas completos, y en los datos correspondientes a la plataforma "Netflix" el principal problema es que la informacion no esta normalizada, sobre todo los campos de fecha donde se observan fechas en formato texto, numero y nulos.
# va a ser necesario limpiar y trasformar estos datos para poder cargarlos a la base de datos**

# %%
# len(df_disney[pd.isna(df_disney.show_id)])
len(df_disney[pd.isna(df_disney.date_added)])
# Out:
# 3

# %% [markdown]
# **Procedemos a transformar los dataframes para poder proceder a la carga**

# %% [markdown]
# Establecemos un codigo de plataforma que permita crear una relacion a una tabla plataforma para saber idenficar a que servicio pertenece cada titulo

# %%
df_netflix['Id_Plataforma'] = 1
df_disney['Id_plataforma'] = 2

# %% [markdown]
# **Porcedemos a transformar las fechas para posteriormente poder relacionarlo a una tabla calendario**

# %%
df_netflix['date_added'] = pd.to_datetime(df_netflix['date_added'], errors='coerce')
df_disney['date_added'] = pd.to_datetime(df_disney['date_added'], errors='coerce')
df_netflix['release_year'] = pd.to_datetime(df_netflix['release_year'], errors='coerce')
df_disney['release_year'] = pd.to_datetime(df_disney['release_year'], errors='coerce', format='%Y')
df_netflix['release_year'] = df_netflix['release_year'].dt.strftime('%Y')
df_disney['release_year'] = df_disney['release_year'].dt.strftime('%Y')
# df_disney['release_year'].head(10)
# Out:
# 0    2016
# 1    1988
# 2    2011
# 3    2021
# 4    2021
# 5    2021
# 6    2021
# 7    2015
# 8    2019
# 9    2008
# Name: release_year, dtype: object
