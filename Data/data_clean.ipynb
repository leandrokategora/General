# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date

# %%
data_netflix = pd.read_csv('./netflix_titles_data.csv', sep=';', encoding='UTF-8')
df_netflix = pd.DataFrame(data_netflix)

data_disney = pd.read_csv('./disney_plus_titles_data.csv', sep=',', encoding='UTF-8')
df_disney = pd.DataFrame(data_disney)

# %% [markdown]
# **Iniciamos con un analisis exploratorio de los datos para determinar que campos tenemos, que tipo de dato estan almacenando y que cantidad de informacion nula hay en el archivo original**

# %%
df_netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_disney.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year    object
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_disney.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_disney.sample(5)
# Out:
#      show_id     type                          title        director  \
# 232     s233  TV Show  Star Wars Vehicle Flythroughs             NaN
# 1422   s1423    Movie            Your Friend the Rat  Jim Capobianco
# 975     s976  TV Show                         Jessie             NaN
# 219     s220  TV Show                Ice Road Rescue             NaN
# 164     s165    Movie      Secrets of the Bull Shark             NaN
#
#                                                    cast         country  \
# 232                                                 NaN             NaN
# 1422  Patton Oswalt, Peter Sohn, Lou Romano, Tony Ru...   United States
# 975   Debby Ryan, Peyton List, Cameron Boyce, Karan ...   United States
# 219        David Wartnaby, Bjørn Lægreid, Thord Paulsen  United Kingdom
# 164                                         Keston John             NaN
#
#              date_added  release_year rating   duration  \
# 232         May 4, 2021          2021   TV-G   1 Season
# 1422  November 12, 2019          2007   TV-G     13 min
# 975   November 12, 2019          2011  TV-PG  4 Seasons
# 219        May 21, 2021          2015  TV-14  5 Seasons
# 164       July 16, 2021          2020  TV-14     44 min
#
#                           listed_in  \
# 232      Anthology, Science Fiction
# 1422      Animation, Comedy, Family
# 975   Comedy, Coming of Age, Family
# 219   Docuseries, Reality, Survival
# 164   Animals & Nature, Documentary
#
#                                             description
# 232   Fly through some of the most iconic Star Wars ...
# 1422  Remy explains why humans and rats should get a...
# 975   A small-town girl becomes a nanny for a quirky...
# 219   Ice Road Rescue follows Norwegian towing teams...
# 164   Secrets of the Bull Shark unravels the mystery...

# %%
df_netflix.sample(5)
# Out:
#      show_id     type                           title  \
# 6864   s6865    Movie                        Gol Maal
# 4922   s4923    Movie                      Mercury 13
# 7602   s7603    Movie  NOVA: Chinese Chariot Revealed
# 2826   s2827  TV Show                     On My Block
# 5294   s5295    Movie                Brother's Shadow
#
#                           director  \
# 6864          Hrishikesh Mukherjee
# 4922  David Sington, Heather Walsh
# 7602                  Giulia Clark
# 2826                           NaN
# 5294                Todd S. Yellin
#
#                                                    cast        country  \
# 6864  Amol Palekar, Bindiya Goswami, Deven Verma, Ut...          India
# 4922                                                NaN  United States
# 7602                                        Eric Meyers  United States
# 2826  Sierra Capri, Jason Genao, Brett Gray, Diego T...  United States
# 5294  Scott Cohen, Judd Hirsch, Susan Floyd, Elliot ...  United States
#
#              date_added release_year rating   duration  \
# 6864  December 31, 2019         1979  TV-PG    137 min
# 4922     April 20, 2018         2018  TV-PG     79 min
# 7602       July 1, 2019         2017  TV-PG     54 min
# 2826     March 11, 2020         2020  TV-14  3 Seasons
# 5294  September 1, 2017         2006  TV-MA     90 min
#
#                                            listed_in  \
# 6864  Classic Movies, Comedies, International Movies
# 4922                                   Documentaries
# 7602                                   Documentaries
# 2826       Romantic TV Shows, TV Comedies, TV Dramas
# 5294                      Dramas, Independent Movies
#
#                                             description
# 6864  When circumstances at work compel Ram to prete...
# 4922  After rigorous testing in 1961, a small group ...
# 7602  The chariot dominated Chinese warfare for mill...
# 2826  In a rough inner-city Los Angeles neighborhood...
# 5294  After serving time in jail, a disgraced son re...

# %%
df_netflix.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8809   8808                  8807           6173
# unique    8809      3                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added release_year  \
# count                 7983           7976             8797         8807
# unique                7693            749             1768           75
# top     David Attenborough  United States  January 1, 2020         2018
# freq                    19           2817              109         1147
#
#        rating  duration                     listed_in  \
# count    8803      8804                          8806
# unique     18       221                           514
# top     TV-MA  1 Season  Dramas, International Movies
# freq     3207      1793                           362
#
#                                               description
# count                                                8806
# unique                                               8774
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %%
df_disney.describe(include='all')
# Out:
#        show_id   type                                             title  \
# count     1450   1450                                              1450
# unique    1450      2                                              1450
# top         s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# freq         1   1052                                                 1
# mean       NaN    NaN                                               NaN
# std        NaN    NaN                                               NaN
# min        NaN    NaN                                               NaN
# 25%        NaN    NaN                                               NaN
# 50%        NaN    NaN                                               NaN
# 75%        NaN    NaN                                               NaN
# max        NaN    NaN                                               NaN
#
#            director            cast        country         date_added  \
# count           977            1260           1231               1447
# unique          609            1193             89                167
# top     Jack Hannah  Winston Hibler  United States  November 12, 2019
# freq             17              10           1005                722
# mean            NaN             NaN            NaN                NaN
# std             NaN             NaN            NaN                NaN
# min             NaN             NaN            NaN                NaN
# 25%             NaN             NaN            NaN                NaN
# 50%             NaN             NaN            NaN                NaN
# 75%             NaN             NaN            NaN                NaN
# max             NaN             NaN            NaN                NaN
#
#         release_year rating  duration                  listed_in  \
# count    1450.000000   1447      1450                       1450
# unique           NaN      9       158                        329
# top              NaN   TV-G  1 Season  Animation, Comedy, Family
# freq             NaN    318       219                        124
# mean     2003.091724    NaN       NaN                        NaN
# std        21.860162    NaN       NaN                        NaN
# min      1928.000000    NaN       NaN                        NaN
# 25%      1999.000000    NaN       NaN                        NaN
# 50%      2011.000000    NaN       NaN                        NaN
# 75%      2018.000000    NaN       NaN                        NaN
# max      2021.000000    NaN       NaN                        NaN
#
#                                               description
# count                                                1450
# unique                                               1448
# top     Cooper and Cami Wrather co-host "Would You Wra...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# **Una vez realizado un analisis inicial de los datos es posible determinar que en la plataforma de "Disney  Plus" los datos estan mas completos, y en los datos correspondientes a la plataforma "Netflix" el principal problema es que la informacion no esta normalizada, sobre todo los campos de fecha donde se observan fechas en formato texto, numero y nulos.
# va a ser necesario limpiar y trasformar estos datos para poder cargarlos a la base de datos**

# %%
# len(df_disney[pd.isna(df_disney.show_id)])
len(df_disney[pd.isna(df_disney.date_added)])
# Out:
# 3

# %% [markdown]
# **Procedemos a transformar los dataframes para poder proceder a la carga**

# %% [markdown]
# Establecemos un codigo de plataforma que permita crear una relacion a una tabla plataforma para saber idenficar a que servicio pertenece cada titulo

# %%
df_netflix['plataforma_id'] = 1
df_disney['plataforma_id'] = 2

# %% [markdown]
# **Porcedemos a transformar las fechas para posteriormente poder relacionarlo a una tabla calendario**

# %%
df_netflix['date_added'] = pd.to_datetime(df_netflix['date_added'], errors='coerce')
df_disney['date_added'] = pd.to_datetime(df_disney['date_added'], errors='coerce')
df_netflix['release_year'] = pd.to_datetime(df_netflix['release_year'], errors='coerce')
df_disney['release_year'] = pd.to_datetime(df_disney['release_year'], errors='coerce', format='%Y')
df_netflix['release_year'] = df_netflix['release_year'].dt.strftime('%Y')
df_disney['release_year'] = df_disney['release_year'].dt.strftime('%Y')
# df_disney['release_year'].head(10)

# %%
df_disney.sample(5)
# Out:
#      show_id     type                               title         director  \
# 799     s800  TV Show  Coop & Cami Ask The World (Shorts)              NaN
# 642     s643    Movie                                Loop     Erica Milsom
# 47       s48    Movie                        Snow Buddies     Robert Vince
# 981     s982    Movie  Journey to the Center of the Earth      Henry Levin
# 1139   s1140    Movie            Pluto's Surprise Package  Charles Nichols
#
#                                                    cast        country  \
# 799                                                 NaN            NaN
# 642   Madison Bandy, Christiano Delgado, Louis Gonza...  United States
# 47    Dominic Scott Kay, John Kapelos, Lise Simms, M...  United States
# 981   Pat Boone, James Mason, Arlene Dahl, Diane Bak...  United States
# 1139                                                NaN  United States
#
#      date_added release_year rating  duration  \
# 799  2019-11-12         2018   TV-G  1 Season
# 642  2020-01-10         2020     PG    12 min
# 47   2021-11-05         2008      G    91 min
# 981  2019-11-12         1959      G   130 min
# 1139 2019-11-12         1949   TV-G     7 min
#
#                                       listed_in  \
# 799     Comedy, Family, Game Show / Competition
# 642                           Animation, Family
# 47               Action-Adventure, Comedy, Kids
# 981   Action-Adventure, Family, Science Fiction
# 1139                  Animation, Comedy, Family
#
#                                             description  plataforma_id
# 799   Cooper and Cami Wrather co-host "Would You Wra...              2
# 642   Adrift on a lake, two kids with different ways...              2
# 47    Disney’s favorite talking pups put one paw in ...              2
# 981   A professor and his colleague engage in a race...              2
# 1139  Pluto tries to bring in the mail, but one parc...              2

# %%
df_netflix.sample(5)
# Out:
#      show_id     type                 title         director  \
# 303     s304    Movie  Esperando la carroza  Alejandro Doria
# 4868   s4869    Movie     The Kissing Booth   Vince Marcello
# 7619   s7620    Movie    November Criminals    Sacha Gervasi
# 8236   s8236  TV Show           The Calling            Bumpy
# 1388   s1389    Movie       The White Tiger    Ramin Bahrani
#
#                                                    cast  \
# 303   Luis Brandoni, China Zorrilla, Antonio Gasalla...
# 4868  Joey King, Joel Courtney, Jacob Elordi, Molly ...
# 7619  Ansel Elgort, Chloë Grace Moretz, David Strath...
# 8236                                                NaN
# 1388  Adarsh Gourav, Rajkummar Rao, Priyanka Chopra ...
#
#                             country date_added release_year rating  duration  \
# 303                       Argentina 2021-08-05         1985  TV-MA    95 min
# 4868  United Kingdom, United States 2018-05-11         2018  TV-14   105 min
# 7619                  United States 2020-07-03         2017  PG-13    86 min
# 8236                          India 2019-04-01         2018  TV-MA  1 Season
# 1388           India, United States 2021-01-22         2021      R   127 min
#
#                                         listed_in  \
# 303   Comedies, Cult Movies, International Movies
# 4868                    Comedies, Romantic Movies
# 7619                            Dramas, Thrillers
# 8236           International TV Shows, Reality TV
# 1388                                       Dramas
#
#                                             description  plataforma_id
# 303   Cora has three sons and a daughter and she´s a...              1
# 4868  When teenager Elle's first kiss leads to a for...              1
# 7619  Dissatisfied with the police’s progress, a tee...              1
# 8236  Food-crazed travel junkies journey across Indi...              1
# 1388  The ambitious driver for a rich Indian family ...              1

# %%
len(df_netflix.description[7264])
# Out:
# 150
