# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
from conect_database import engine

# %%
data_netflix = pd.read_csv('../netflix_titles_data.csv', sep=';', encoding='UTF-8')
df_netflix = pd.DataFrame(data_netflix)

data_disney = pd.read_csv('../disney_plus_titles_data.csv', sep=',', encoding='UTF-8')
df_disney = pd.DataFrame(data_disney)

# %% [markdown]
# **Iniciamos con un analisis exploratorio de los datos para determinar que campos tenemos, que tipo de dato estan almacenando y que cantidad de informacion nula hay en el archivo original**

# %%
df_netflix.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_disney.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df_netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year    object
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_disney.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df_disney.sample(5)
# Out:
#      show_id     type                        title  \
# 1124   s1125  TV Show           Phil of the Future
# 741     s742    Movie                 Beach Picnic
# 474     s475  TV Show  Cosmos: A Spacetime Odyssey
# 1082   s1083    Movie                    Minutemen
# 1116   s1117    Movie          Paris To Pittsburgh
#
#                                 director  \
# 1124                                 NaN
# 741                       Clyde Geronimi
# 474                                  NaN
# 1082                           Lev Spiro
# 1116  Sidney Beaumont, Michael Bonfiglio
#
#                                                    cast        country  \
# 1124  Ricky Ullman, Amy Bruckner, Craig Anton, Lise ...  United States
# 741                                                 NaN  United States
# 474                       Neil Tyson, Stoney Emshwiller  United States
# 1082  Jason Dolley, Luke Benward, Nicholas Braun, Ch...  United States
# 1116                                   Rachel Brosnahan  United States
#
#              date_added  release_year rating   duration  \
# 1124  November 12, 2019          2003   TV-G  2 Seasons
# 741   November 12, 2019          1939   TV-G      9 min
# 474       July 10, 2020          2013  TV-PG   1 Season
# 1082  November 12, 2019          2008   TV-G     91 min
# 1116  November 12, 2019          2018  TV-PG     77 min
#
#                                       listed_in  \
# 1124                Comedy, Coming of Age, Kids
# 741                   Animation, Comedy, Family
# 474        Action-Adventure, Docuseries, Family
# 1082  Action-Adventure, Comedy, Science Fiction
# 1116                                Documentary
#
#                                             description
# 1124  Phil is just your average teenager – whose fam...
# 741   Donald Duck and Pluto are at the beach. See de...
# 474   A 13-part adventure across the universe of spa...
# 1082  Three teen outcasts invent a time machine to s...
# 1116  Americans are demanding action on climate chan...

# %%
df_netflix.sample(5)
# Out:
#      show_id     type                      title             director  \
# 2915   s2916    Movie                   Liefling         Brian Webber
# 366     s367  TV Show                    Glow Up                  NaN
# 491     s492    Movie                 Home Again  Hallie Meyers-Shyer
# 6858   s6859    Movie  God Bless the Broken Road         Harold Cronk
# 3112   s3113    Movie           Being Mrs Elliot          Omoni Oboli
#
#                                                    cast         country  \
# 2915  Lika Berning, Bobby van Jaarsveld, Marlee van ...    South Africa
# 366                                                 NaN  United Kingdom
# 491   Reese Witherspoon, Michael Sheen, Candice Berg...   United States
# 6858  Patrika Darbo, Kim Delaney, Jordin Sparks, Mak...   United States
# 3112  Omoni Oboli, Majid Michel, Ayo Makun, Uru Eke,...         Nigeria
#
#              date_added release_year rating   duration  \
# 2915  February 14, 2020         2010  TV-PG    118 min
# 366       July 30, 2021         2021  TV-14  3 Seasons
# 491        July 8, 2021         2017  PG-13     97 min
# 6858   February 9, 2019         2018     PG    111 min
# 3112  December 20, 2019         2014  TV-14    113 min
#
#                                               listed_in  \
# 2915   Comedies, International Movies, Music & Musicals
# 366   British TV Shows, International TV Shows, Real...
# 491                   Comedies, Dramas, Romantic Movies
# 6858  Children & Family Movies, Dramas, Faith & Spir...
# 3112      Dramas, International Movies, Romantic Movies
#
#                                             description
# 2915  An adventure-loving young woman catches the at...
# 366   In this competition show, aspiring makeup arti...
# 491   A newly single mom takes in three young male f...
# 6858  After a young mother is widowed by war, her fa...
# 3112  When a scorned wife from the city shares a cab...

# %%
df_netflix.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8809   8808                  8807           6173
# unique    8809      3                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added release_year  \
# count                 7983           7976             8797         8807
# unique                7693            749             1768           75
# top     David Attenborough  United States  January 1, 2020         2018
# freq                    19           2817              109         1147
#
#        rating  duration                     listed_in  \
# count    8803      8804                          8806
# unique     18       221                           514
# top     TV-MA  1 Season  Dramas, International Movies
# freq     3207      1793                           362
#
#                                               description
# count                                                8806
# unique                                               8774
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4

# %%
df_disney.describe(include='all')
# Out:
#        show_id   type                                             title  \
# count     1450   1450                                              1450
# unique    1450      2                                              1450
# top         s1  Movie  Duck the Halls: A Mickey Mouse Christmas Special
# freq         1   1052                                                 1
# mean       NaN    NaN                                               NaN
# std        NaN    NaN                                               NaN
# min        NaN    NaN                                               NaN
# 25%        NaN    NaN                                               NaN
# 50%        NaN    NaN                                               NaN
# 75%        NaN    NaN                                               NaN
# max        NaN    NaN                                               NaN
#
#            director            cast        country         date_added  \
# count           977            1260           1231               1447
# unique          609            1193             89                167
# top     Jack Hannah  Winston Hibler  United States  November 12, 2019
# freq             17              10           1005                722
# mean            NaN             NaN            NaN                NaN
# std             NaN             NaN            NaN                NaN
# min             NaN             NaN            NaN                NaN
# 25%             NaN             NaN            NaN                NaN
# 50%             NaN             NaN            NaN                NaN
# 75%             NaN             NaN            NaN                NaN
# max             NaN             NaN            NaN                NaN
#
#         release_year rating  duration                  listed_in  \
# count    1450.000000   1447      1450                       1450
# unique           NaN      9       158                        329
# top              NaN   TV-G  1 Season  Animation, Comedy, Family
# freq             NaN    318       219                        124
# mean     2003.091724    NaN       NaN                        NaN
# std        21.860162    NaN       NaN                        NaN
# min      1928.000000    NaN       NaN                        NaN
# 25%      1999.000000    NaN       NaN                        NaN
# 50%      2011.000000    NaN       NaN                        NaN
# 75%      2018.000000    NaN       NaN                        NaN
# max      2021.000000    NaN       NaN                        NaN
#
#                                               description
# count                                                1450
# unique                                               1448
# top     Cooper and Cami Wrather co-host "Would You Wra...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %% [markdown]
# **Una vez realizado un analisis inicial de los datos es posible determinar que en la plataforma de "Disney  Plus" los datos estan mas completos, y en los datos correspondientes a la plataforma "Netflix" el principal problema es que la informacion no esta normalizada, sobre todo los campos de fecha donde se observan fechas en formato texto, numero y nulos.
# va a ser necesario limpiar y trasformar estos datos para poder cargarlos a la base de datos**

# %%
# len(df_disney[pd.isna(df_disney.show_id)])
len(df_disney[pd.isna(df_disney.date_added)])
# Out:
# 3

# %% [markdown]
# **Procedemos a transformar los dataframes para poder proceder a la carga**

# %% [markdown]
# Establecemos un codigo de plataforma que permita crear una relacion a una tabla plataforma para saber idenficar a que servicio pertenece cada titulo

# %%
df_netflix['plataforma_id'] = 1
df_disney['plataforma_id'] = 2

# %% [markdown]
# **Porcedemos a transformar las fechas para posteriormente poder relacionarlo a una tabla calendario**

# %%
df_netflix['date_added'] = pd.to_datetime(df_netflix['date_added'], errors='coerce')
df_disney['date_added'] = pd.to_datetime(df_disney['date_added'], errors='coerce')
df_netflix['release_year'] = pd.to_datetime(df_netflix['release_year'], errors='coerce')
df_disney['release_year'] = pd.to_datetime(df_disney['release_year'], errors='coerce', format='%Y')
df_netflix['release_year'] = df_netflix['release_year'].dt.strftime('%Y')
df_disney['release_year'] = df_disney['release_year'].dt.strftime('%Y')
# df_disney['release_year'].head(10)

# %%
df_disney.sample(5)
# Out:
#      show_id   type                                              title  \
# 1008   s1009  Movie  LEGO Star Wars: The New Yoda Chronicles - Raid...
# 1339   s1340  Movie                                 The Sound of Music
# 1424   s1425  Movie                                             Zapped
# 1416   s1417  Movie                                     Wreck-It Ralph
# 958     s959  Movie                     Ice Age: The Great Egg-Scapade
#
#             director                                               cast  \
# 1008  Michael Hegner  Tom Kane, Anthony Daniels, Matt Sloan, Trevor ...
# 1339     Robert Wise  Julie Andrews, Christopher Plummer, Richard Ha...
# 1424   Peter DeLuise  Zendaya , Chanelle Peloso, Spencer Boldman, Em...
# 1416      Rich Moore  John Reilly, Sarah Silverman, Jack McBrayer, J...
# 958   Ricardo Curtis  Raymond Albert Romano, John Leguizamo, Denis L...
#
#                     country date_added release_year rating duration  \
# 1008         Denmark, China 2019-11-12         2014  TV-Y7   24 min
# 1339          United States 2019-11-12         1965      G  175 min
# 1424  Canada, United States 2019-11-12         2014   TV-G   95 min
# 1416          United States 2019-11-12         2012     PG  103 min
# 958           United States 2019-11-12         2016   TV-G   26 min
#
#                                    listed_in  \
# 1008     Action-Adventure, Animation, Comedy
# 1339        Biographical, Family, Historical
# 1424  Comedy, Coming of Age, Science Fiction
# 1416     Action-Adventure, Animation, Comedy
# 958                Animation, Comedy, Family
#
#                                             description  plataforma_id
# 1008  Luke Skywalker attempts a daring raid on Corus...              2
# 1339  A governess wins the hearts of many and leads ...              2
# 1424  Zoey discovers a magical app that can control ...              2
# 1416  Ralph sets out to prove that he is a true hero...              2
# 958   Our favorite Ice Age herd embarks on a rescue ...              2

# %%
df_netflix.sample(5)
# Out:
#      show_id     type                                   title        director  \
# 6491   s6492    Movie  Clarence Clemons: Who Do I Think I Am?       Nick Mead
# 534     s535    Movie                     Si Doel the Movie 2      Rano Karno
# 14       s15  TV Show         Crime Stories: India Detectives             NaN
# 1210   s1211  TV Show                              Love Alarm             NaN
# 6130   s6131    Movie                      Amar Akbar Anthony  Manmohan Desai
#
#                                                    cast        country  \
# 6491                                   Clarence Clemons  United States
# 534   Maudy Koesnaedi, Rano Karno, Cornelia Agatha, ...      Indonesia
# 14                                                  NaN            NaN
# 1210  Kim So-hyun, Jung Ga-ram, Song Kang, Ko Min-si...    South Korea
# 6130  Vinod Khanna, Rishi Kapoor, Amitabh Bachchan, ...          India
#
#      date_added release_year rating   duration  \
# 6491 2019-11-14         2019  TV-MA     88 min
# 534  2021-07-06         2019   TV-G     95 min
# 14   2021-09-22         2021  TV-MA   1 Season
# 1210 2021-03-12         2021  TV-MA  2 Seasons
# 6130 2019-12-31         1977  TV-14    172 min
#
#                                               listed_in  \
# 6491                    Documentaries, Music & Musicals
# 534                        Dramas, International Movies
# 14         British TV Shows, Crime TV Shows, Docuseries
# 1210  International TV Shows, Korean TV Shows, Roman...
# 6130       Action & Adventure, Classic Movies, Comedies
#
#                                             description  plataforma_id
# 6491  This intimate documentary follows the life of ...              1
# 534   As Sarah and her child look to settle in Jakar...              1
# 14    Cameras following Bengaluru police on the job ...              1
# 1210  In a world where an app alerts people if someo...              1
# 6130  Abandoned in a park by their father, Amar, Akb...              1

# %%
len(df_netflix.description[7264])
# Out:
# 150

# %%
df_carga = pd.concat(df_disney, df_netflix)
df_carga.sample(10)

# %% [markdown]
# **IMPORTAMOS A LA BASE DE DATOS LA INFORMACION PROCESADA**

# %%
import sqlalchemy as sa
import urllib
import pyodbc
parameters = urllib.parse.quote_plus("DRIVER=MySQL ODBC 8.0 Unicode Driver;"
                                     "Server=127.0.0.1;"
                                     "DATABASE=rkd_challenge;"
                                     "UID=root;"
                                     "PWD=")

try:
    engine = sa.create_engine("mysql+pyodbc:///?odbc_conect={}".format(parameters))
    print('Conexion exitosa')
except Exception as ex:
    print(ex)
# Out:
# Conexion exitosa

# %%
try:
    df_disney.to_sql('shows', con=engine, if_exists='append', index=False)
    print('Carga Exitosa')
except Exception as ex:
    print('Error al cargar')
    print(ex)
# Out:
# Error al cargar
# (pyodbc.InterfaceError) ('IM002', '[IM002] [Microsoft][Administrador de controladores ODBC] No se encuentra el nombre del origen de datos y no se especificó ningún controlador predeterminado (0) (SQLDriverConnect)')
# (Background on this error at: https://sqlalche.me/e/14/rvf5)
